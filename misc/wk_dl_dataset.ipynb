# %%
from pathlib import Path
from collections import namedtuple

import numpy as np
import matplotlib.pyplot as plt
from pyometiff import OMETIFFWriter
import webknossos as wk

import dask.array as da

import pandas as pd
from skimage.measure import label, regionprops_table
from skimage.color import label2rgb

from webknossos import BoundingBox
import matplotlib.pyplot as plt

from webknossos_utils import Pixel_size, Annotation
import napari

# %%
# this comes from the WEBKNOSSOS website, under the user settings
AUTH_TOKEN = "S-QRDIegZYX0IM1lXmyiJg" # from gisela
WK_TIMEOUT="3600" # in seconds
ORG_ID = "83d574429f8bc523" # gisela's webknossos

#sample1   = Annotation("6644c04d0100004a01fa11af", "deprecated","60_2_5R")
#sample2    = Annotation("664316880100008a049e890e", "deprecated","60_2_3L")
id_1 = "6644c04d0100004a01fa11af"
id_2 = "664316880100008a049e890e"
id_3 = "664606440100005102550210"

ids = [id_1, id_2, id_3]

#666c4ae70100002b015e2344
# the dataset url comes from the WEBKNOSSOS website, open the image of interest from the dashboard and check
# I removed the view information

ANNOTATION_ID = id_2

with wk.webknossos_context(token=AUTH_TOKEN):

    for i in ids:
        annotations = wk.Annotation.open_as_remote_dataset(annotation_id_or_url=i)
        DATASET_NAME = annotations._properties.id['name']

        print(f"ds name {DATASET_NAME}")

        wk.Dataset.download(dataset_name_or_url=DATASET_NAME)

    # ann = wk.Annotation.download(annotation_id_or_url=id_2, path="./gisela_2")

    # ann = wk.Annotation.download(annotation_id_or_url=id_3, pat="./gisela_3")


    #ann.save("gisela_1.zip")
    #lbl_layers = annotations.get_segmentation_layers()

    #DATASET_NAME = annotations._properties.id['name']
    #ds = wk.Dataset.open_remote(dataset_name_or_url=DATASET_NAME, organization_id=ORG_ID)
    #wk.Dataset.download(dataset_name_or_url=DATASET_NAME, organization_id=ORG_ID, path="downloads", exist_ok=True)
    
    #img_layer = ds.get_color_layers()
    #assert len(img_layer) == 1, "more than an image, this is unexpected for this project"
    #img_layer = img_layer[0]

    #dataset = wk.Dataset.open_remote(DATASET_URL)
    #img_data = dataset.get_color_layer().get_finest_mag().read()
# Out:
# /home/xfolka/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/webknossos/annotation/annotation.py:455: UserWarning: [INFO] Omitting the volume layer annotation data for layers ['Myelin', 'Mitochondria', 'Dystrophic_myelin', 'Axon'], as their location is not referenced in the NML.
#   warnings.warn(
# ds name 60_2_5R
# /home/xfolka/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/rich/live.py:
# 221: UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 28
#      24     DATASET_NAME = annotations._properties.id['name']
#      26     print(f"ds name {DATASET_NAME}")
# ---> 28     wk.Dataset.download(dataset_name_or_url=DATASET_NAME)
#      30 # ann = wk.Annotation.download(annotation_id_or_url=id_2, path="./gisela_2")
#      31
#      32 # ann = wk.Annotation.download(annotation_id_or_url=id_3, pat="./gisela_3")
#    (...)
#      46 #dataset = wk.Dataset.open_remote(DATASET_URL)
#      47 #img_data = dataset.get_color_layer().get_finest_mag().read()
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/webknossos/dataset/dataset.py:546, in Dataset.download(cls, dataset_name_or_url, organization_id, sharing_token, webknossos_url, bbox, layers, mags, path, exist_ok)
#     543     layers = [layers]
#     545 with context_manager:
# --> 546     return download_dataset(
#     547         dataset_name,
#     548         organization_id=organization_id,
#     549         sharing_token=sharing_token,
#     550         bbox=bbox,
#     551         layers=layers,
#     552         mags=mags,
#     553         path=path,
#     554         exist_ok=exist_ok,
#     555     )
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/webknossos/client/_download_dataset.py:111, in download_dataset(dataset_name, organization_id, sharing_token, bbox, layers, mags, path, exist_ok)
#     102 for chunk in track(
#     103     list(
#     104         aligned_bbox.chunk(
#    (...)
#     108     description=f"Downloading layer={layer.name} mag={mag}",
#     109 ):
#     110     chunk_in_mag = chunk.in_mag(mag)
# --> 111     chunk_bytes, missing_buckets = datastore_client.dataset_get_raw_data(
#     112         organization_name=organization_id,
#     113         dataset_name=dataset_name,
#     114         data_layer_name=layer_name,
#     115         mag=mag.to_long_layer_name(),
#     116         token=optional_datastore_token,
#     117         x=chunk.topleft.x,
#     118         y=chunk.topleft.y,
#     119         z=chunk.topleft.z,
#     120         width=chunk_in_mag.size.x,
#     121         height=chunk_in_mag.size.y,
#     122         depth=chunk_in_mag.size.z,
#     123     )
#     124     assert (
#     125         missing_buckets == "[]"
#     126     ), f"Download contained missing buckets {missing_buckets}."
#     127     data = np.frombuffer(
#     128         chunk_bytes, dtype=layer.dtype_per_channel
#     129     ).reshape(layer.num_channels, *chunk_in_mag.size, order="F")
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/webknossos/client/api_client/datastore_api_client.py:84, in DatastoreApiClient.dataset_get_raw_data(self, organization_name, dataset_name, data_layer_name, mag, token, x, y, z, width, height, depth)
#      73 route = f"/datasets/{organization_name}/{dataset_name}/layers/{data_layer_name}/data"
#      74 query: Query = {
#      75     "mag": mag,
#      76     "x": x,
#    (...)
#      82     "token": token,
#      83 }
# ---> 84 response = self._get(route, query)
#      85 return response.content, response.headers.get("MISSING-BUCKETS")
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/webknossos/client/api_client/_abstract_api_client.py:111, in AbstractApiClient._get(self, route, query, timeout_seconds)
#     105 def _get(
#     106     self,
#     107     route: str,
#     108     query: Optional[Query] = None,
#     109     timeout_seconds: Optional[float] = None,
#     110 ) -> httpx.Response:
# --> 111     return self._request("GET", route, query, timeout_seconds=timeout_seconds)
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/webknossos/client/api_client/_abstract_api_client.py:166, in AbstractApiClient._request(self, method, route, query, body_json, multipart_data, files, retry_count, timeout_seconds)
#     164 response = None
#     165 for _ in range(retry_count + 1):
# --> 166     response = httpx.request(
#     167         method,
#     168         url,
#     169         params=self._omit_none_values_in_query(query),
#     170         json=body_json,
#     171         data=multipart_data,
#     172         files=files,
#     173         headers=self.headers,
#     174         timeout=timeout_seconds or self.timeout_seconds,
#     175     )
#     176     if response.status_code == 200 or response.status_code == 400:
#     177         # Stop retrying in case of success or bad request
#     178         break
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/httpx/_api.py:100, in request(method, url, params, content, data, files, json, headers, cookies, auth, proxies, timeout, follow_redirects, verify, cert, trust_env)
#      42 """
#      43 Sends an HTTP request.
#      44
#    (...)
#      90 ```
#      91 """
#      92 with Client(
#      93     cookies=cookies,
#      94     proxies=proxies,
#    (...)
#      98     trust_env=trust_env,
#      99 ) as client:
# --> 100     return client.request(
#     101         method=method,
#     102         url=url,
#     103         content=content,
#     104         data=data,
#     105         files=files,
#     106         json=json,
#     107         params=params,
#     108         headers=headers,
#     109         auth=auth,
#     110         follow_redirects=follow_redirects,
#     111     )
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/httpx/_client.py:814, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     799     warnings.warn(message, DeprecationWarning)
#     801 request = self.build_request(
#     802     method=method,
#     803     url=url,
#    (...)
#     812     extensions=extensions,
#     813 )
# --> 814 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/httpx/_client.py:915, in Client.send(self, request, stream, auth, follow_redirects)
#     913 except BaseException as exc:
#     914     response.close()
# --> 915     raise exc
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/httpx/_client.py:909, in Client.send(self, request, stream, auth, follow_redirects)
#     907 try:
#     908     if not stream:
# --> 909         response.read()
#     911     return response
#     913 except BaseException as exc:
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/httpx/_models.py:805, in Response.read(self)
#     801 """
#     802 Read and return the response content.
#     803 """
#     804 if not hasattr(self, "_content"):
# --> 805     self._content = b"".join(self.iter_bytes())
#     806 return self._content
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/httpx/_models.py:823, in Response.iter_bytes(self, chunk_size)
#     821 chunker = ByteChunker(chunk_size=chunk_size)
#     822 with request_context(request=self._request):
# --> 823     for raw_bytes in self.iter_raw():
#     824         decoded = decoder.decode(raw_bytes)
#     825         for chunk in chunker.decode(decoded):
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/httpx/_models.py:881, in Response.iter_raw(self, chunk_size)
#     878 chunker = ByteChunker(chunk_size=chunk_size)
#     880 with request_context(request=self._request):
# --> 881     for raw_stream_bytes in self.stream:
#     882         self._num_bytes_downloaded += len(raw_stream_bytes)
#     883         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/httpx/_client.py:123, in BoundSyncStream.__iter__(self)
#     122 def __iter__(self) -> typing.Iterator[bytes]:
# --> 123     for chunk in self._stream:
#     124         yield chunk
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/httpx/_transports/default.py:104, in ResponseStream.__iter__(self)
#     102 def __iter__(self) -> typing.Iterator[bytes]:
#     103     with map_httpcore_exceptions():
# --> 104         for part in self._httpcore_stream:
#     105             yield part
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:347, in ConnectionPoolByteStream.__iter__(self)
#     346 def __iter__(self) -> Iterator[bytes]:
# --> 347     for part in self._stream:
#     348         yield part
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/httpcore/_sync/http11.py:325, in HTTP11ConnectionByteStream.__iter__(self)
#     323 with ShieldCancellation():
#     324     self.close()
# --> 325 raise exc
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/httpcore/_sync/http11.py:317, in HTTP11ConnectionByteStream.__iter__(self)
#     315 try:
#     316     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 317         for chunk in self._connection._receive_response_body(**kwargs):
#     318             yield chunk
#     319 except BaseException as exc:
#     320     # If we get an exception while streaming the response,
#     321     # we want to close the response (and possibly the connection)
#     322     # before raising that exception.
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_body(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Data):
#     188         yield bytes(event.data)
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/httpcore/_sync/http11.py:200, in HTTP11Connection._receive_event(self, timeout)
#     197     event = self._h11_state.next_event()
#     199 if event is h11.NEED_DATA:
# --> 200     data = self._network_stream.read(
#     201         self.READ_NUM_BYTES, timeout=timeout
#     202     )
#     204     # If we feed this case through h11 we'll raise an exception like:
#     205     #
#     206     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     210     # perspective. Instead we handle this case distinctly and treat
#     211     # it as a ConnectError.
#     212     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/projects/wk_stardist_hhd_at_sem/.venv/lib/python3.10/site-packages/httpcore/_backends/sync.py:28, in SyncStream.read(self, max_bytes, timeout)
#      26 with map_exceptions(exc_map):
#      27     self._sock.settimeout(timeout)
# ---> 28     return self._sock.recv(max_bytes)
#
# File /usr/lib/python3.10/ssl.py:1288, in SSLSocket.recv(self, buflen, flags)
#    1284     if flags != 0:
#    1285         raise ValueError(
#    1286             "non-zero flags not allowed in calls to recv() on %s" %
#    1287             self.__class__)
# -> 1288     return self.read(buflen)
#    1289 else:
#    1290     return super().recv(buflen, flags)
#
# File /usr/lib/python3.10/ssl.py:1161, in SSLSocket.read(self, len, buffer)
#    1159         return self._sslobj.read(len, buffer)
#    1160     else:
# -> 1161         return self._sslobj.read(len)
#    1162 except SSLError as x:
#    1163     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
